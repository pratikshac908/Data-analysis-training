# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaini9/Data-Analytics-Training/blob/main/Python/practice/OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#creating a class

# %%
class MyClass:
  x=6

# %%
p1=MyClass()
print(p1.x)
# Out:
# 6

# %%
p1=MyClass()
p2=MyClass()
p3=MyClass()

print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 6
# 6
# 6

# %% [markdown]
# constructor in python

# %%
class Person:
  def __init__(self,name,age):
    self.name=name
    self.age=age

p1=Person("pratiksha",23)

print(p1.name)
print(p1.age)
# Out:
# pratiksha
# 23

# %% [markdown]
# #practice

# %%
class Car:

    def __init__(self, name, color):
        self.name = name
        self.color = color

    def display(self):
        print("car name:", self.name)
        print("car color:", self.color)

car1 = Car("BMW", "Black")
car2 = Car("toyota", "White")
car1.display()
car2.display()
# Out:
# car name: BMW
# car color: Black
# car name: toyota
# car color: White
