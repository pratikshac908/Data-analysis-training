# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaini9/Data-Analytics-Training/blob/main/Pandas/Assignment/25%2B_conditional_practice_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv("/content/titanic_dataset.csv")
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.loc[df["Fare"] > 50, ["Fare", "Age", "Embarked"]]
# Out:
#           Fare   Age Embarked
# 1      71.2833  38.0        C
# 3      53.1000  35.0        S
# 6      51.8625  54.0        S
# 27    263.0000  19.0        S
# 31    146.5208   NaN        C
# ...        ...   ...      ...
# 1291  164.8667  30.0        S
# 1293   59.4000  22.0        C
# 1298  211.5000  50.0        C
# 1302   90.0000  37.0        Q
# 1305  108.9000  39.0        C
#
# [240 rows x 3 columns]

# %%
df.loc[df["Fare"] > 50 , ["Fare", "Age", "Embarked"]]
# Out:
#           Fare   Age Embarked
# 1      71.2833  38.0        C
# 3      53.1000  35.0        S
# 6      51.8625  54.0        S
# 27    263.0000  19.0        S
# 31    146.5208   NaN        C
# ...        ...   ...      ...
# 1291  164.8667  30.0        S
# 1293   59.4000  22.0        C
# 1298  211.5000  50.0        C
# 1302   90.0000  37.0        Q
# 1305  108.9000  39.0        C
#
# [240 rows x 3 columns]

# %%
df.loc[df["Age"] < 50, ["Name","Sex"]]
# Out:
#                                                    Name     Sex
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1300                          Peacock, Miss. Treasteall  female
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  female
# 1303                     Henriksson, Miss. Jenny Lovisa  female
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
#
# [936 rows x 2 columns]

# %%
df.loc[df["Survived"]==1,:]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 8               9         1       3
# 9              10         1       2
# ...           ...       ...     ...
# 1300         1301         1       3
# 1301         1302         1       3
# 1302         1303         1       1
# 1303         1304         1       3
# 1305         1306         1       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %% [markdown]
# pclass 1 ma janey male haru ko naam ra fare

# %%
df.loc[(df["Pclass"] == 1) & (df["Sex"] == "male"), ["Fare","Name"]]
# Out:
#           Fare                            Name
# 6      51.8625         McCarthy, Mr. Timothy J
# 23     35.5000    Sloper, Mr. William Thompson
# 27    263.0000  Fortune, Mr. Charles Alexander
# 30     27.7208        Uruchurtu, Don. Manuel E
# 34     82.1708         Meyer, Mr. Edgar Joseph
# ...        ...                             ...
# 1269   50.0000     Hipkins, Mr. William Edward
# 1281   93.5000      Payne, Mr. Vivian Ponsonby
# 1294   47.1000          Carrau, Mr. Jose Pedro
# 1295   27.7208    Frauenthal, Mr. Isaac Gerald
# 1298  211.5000      Widener, Mr. George Dunton
#
# [179 rows x 2 columns]

# %% [markdown]
# 22 wa 22 vanda sano age ko min fare

# %%
df.loc[(df["Age"] > 22) & (df["Fare"] == df["Fare"].min()), ["Fare","Name"]]
# Out:
#       Fare                             Name
# 179    0.0              Leonard, Mr. Lionel
# 263    0.0            Harrison, Mr. William
# 271    0.0     Tornquist, Mr. William Henry
# 597    0.0              Johnson, Mr. Alfred
# 806    0.0           Andrews, Mr. Thomas Jr
# 822    0.0  Reuchlin, Jonkheer. John George
# 1263   0.0          Ismay, Mr. Joseph Bruce

# %% [markdown]
# kun class ma gako manxe dherai bachey ta

# %%
df.groupby("Pclass")["Survived"].sum()
# Out:
# Pclass
# 1    186
# 2    117
# 3    191
# Name: Survived, dtype: int64

# %% [markdown]
# Which one is more common, male or female?

# %%
df.loc[df["Pclass"] == 1, "Sex"].value_counts()
# Out:
# Sex
# male      179
# female    144
# Name: count, dtype: int64

# %%
df.loc[df["Age"] < 22, "Fare"].max()
# Out:
# 263.0

# %%
# syntax for loc
#df.loc[row_condition, column_selection]

# %%
df[df["Age"]>30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[df["Age"] > 30, :]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Passengers who survived
df.loc[df["Survived"] == 1, ["Name","Age","Survived"]]
# Out:
#                                                   Name   Age  Survived
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                               Heikkinen, Miss. Laina  26.0         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0         1
# ..                                                 ...   ...       ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0         1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0         1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0         1
# 887                       Graham, Miss. Margaret Edith  19.0         1
# 889                              Behr, Mr. Karl Howell  26.0         1
#
# [342 rows x 3 columns]

# %%
df.loc[df["Survived"] == 0, ["Name","Age","Survived","Embarked"]]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Passengers in 1st class
df.loc[df["Pclass"]==1,["Name","Age","Pclass","Sex"]]
# Out:
#                                                   Name   Age  Pclass     Sex
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1  female
# 6                              McCarthy, Mr. Timothy J  54.0       1    male
# 11                            Bonnell, Miss. Elizabeth  58.0       1  female
# 23                        Sloper, Mr. William Thompson  28.0       1    male
# ..                                                 ...   ...     ...     ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0       1  female
# 872                           Carlsson, Mr. Frans Olof  33.0       1    male
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0       1  female
# 887                       Graham, Miss. Margaret Edith  19.0       1  female
# 889                              Behr, Mr. Karl Howell  26.0       1    male
#
# [216 rows x 4 columns]

# %%
df.loc[df["Pclass"]==1,["Name","Age","Pclass","Sex"]]

# %%
# Age > 30 AND Survived
df.loc[(df["Age"] > 30) & (df["Survived"] == 0), :]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 6              7         0       1
# 13            14         0       3
# 18            19         0       3
# 20            21         0       2
# ..           ...       ...     ...
# 872          873         0       1
# 873          874         0       3
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Age < 18 OR Female

# %%
# make a 5 question  live and practice

# %%
# find out the members numbers  of 3rd class who is female
df.loc[(df["Pclass"]==3) & (df["Sex"]=="female"),["Pclass","Sex","Name"]]
# Out:
#      Pclass     Sex                                               Name
# 2         3  female                             Heikkinen, Miss. Laina
# 8         3  female  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10        3  female                    Sandstrom, Miss. Marguerite Rut
# 14        3  female               Vestrom, Miss. Hulda Amanda Adolfina
# 18        3  female  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# ..      ...     ...                                                ...
# 863       3  female                  Sage, Miss. Dorothy Edith "Dolly"
# 875       3  female                   Najib, Miss. Adele Kiamie "Jane"
# 882       3  female                       Dahlberg, Miss. Gerda Ulrika
# 885       3  female               Rice, Mrs. William (Margaret Norton)
# 888       3  female           Johnston, Miss. Catherine Helen "Carrie"
#
# [144 rows x 3 columns]

# %%
# find out the members numbers  of 3rd class who is male

# %%
# Female passengers older than 25
df.loc[(df["Sex"] == "female") & (df["Age"] > 25), ["Name", "Age", "Pclass"]]
# Out:
#                                                   Name   Age  Pclass
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1
# 2                               Heikkinen, Miss. Laina  26.0       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0       3
# 11                            Bonnell, Miss. Elizabeth  58.0       1
# ..                                                 ...   ...     ...
# 866                       Duran y More, Miss. Asuncion  27.0       2
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0       1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  28.0       2
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0       1
# 885               Rice, Mrs. William (Margaret Norton)  39.0       3
#
# [139 rows x 3 columns]

# %%
# Female passengers older than 25

# %%
# Average age of survivors
df.loc[df["Survived"]==1,"Age"].mean()
# Out:
# np.float64(28.343689655172415)

# %%
#Rich passengers (Fare > 100) who survived only find name and age

# %%
# find the name and age of Children (<15) in 3rd class

# %%
# Count passengers older than 60
df.loc[df["Age"] > 60, :].shape[0]

# %%
# your task take a another datasets and make a 30 to 50 question and do a practcie like this

# %% [markdown]
# Show all passengers who survived.

# %%
df.loc[df["Survived"] == 1, :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 8               9         1       3
# 9              10         1       2
# ...           ...       ...     ...
# 1300         1301         1       3
# 1301         1302         1       3
# 1302         1303         1       1
# 1303         1304         1       3
# 1305         1306         1       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %% [markdown]
# 2. Show all passengers who did not survive

# %%
df.loc[df["Survived"] == 0, :]
# Out:
#       PassengerId  Survived  Pclass                            Name   Sex  \
# 0               1         0       3         Braund, Mr. Owen Harris  male
# 4               5         0       3        Allen, Mr. William Henry  male
# 5               6         0       3                Moran, Mr. James  male
# 6               7         0       1         McCarthy, Mr. Timothy J  male
# 7               8         0       3  Palsson, Master. Gosta Leonard  male
# ...           ...       ...     ...                             ...   ...
# 1298         1299         0       1      Widener, Mr. George Dunton  male
# 1304         1305         0       3              Spector, Mr. Woolf  male
# 1306         1307         0       3    Saether, Mr. Simon Sivertsen  male
# 1307         1308         0       3             Ware, Mr. Frederick  male
# 1308         1309         0       3        Peter, Master. Michael J  male
#
#        Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# 3. Age greater than 30

# %%
df.loc[df["Age"] > 30, :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 3               4         1       1
# 4               5         0       3
# 6               7         0       1
# 11             12         1       1
# ...           ...       ...     ...
# 1295         1296         0       1
# 1298         1299         0       1
# 1302         1303         1       1
# 1305         1306         1       1
# 1306         1307         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# 6                               McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %% [markdown]
# 4. Age less than 18

# %%
df.loc[df["Age"] < 18, :]
# Out:
#       PassengerId  Survived  Pclass                                  Name  \
# 7               8         0       3        Palsson, Master. Gosta Leonard
# 9              10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10             11         1       3       Sandstrom, Miss. Marguerite Rut
# 14             15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16             17         0       3                  Rice, Master. Eugene
# ...           ...       ...     ...                                   ...
# 1270         1271         0       3           Asplund, Master. Carl Edgar
# 1280         1281         0       3           Palsson, Master. Paul Folke
# 1283         1284         0       3         Abbott, Master. Eugene Joseph
# 1294         1295         0       1                Carrau, Mr. Jose Pedro
# 1300         1301         1       3             Peacock, Miss. Treasteall
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# 5. Fare more than 100

# %%
df.loc[df["Fare"] > 100, :]
# Out:
#       PassengerId  Survived  Pclass  \
# 27             28         0       1
# 31             32         1       1
# 88             89         1       1
# 118           119         0       1
# 195           196         1       1
# ...           ...       ...     ...
# 1262         1263         1       1
# 1266         1267         1       1
# 1291         1292         1       1
# 1298         1299         0       1
# 1305         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 27                    Fortune, Mr. Charles Alexander    male  19.0      3
# 31    Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 88                        Fortune, Miss. Mabel Helen  female  23.0      3
# 118                         Baxter, Mr. Quigg Edmond    male  24.0      0
# 195                             Lurette, Miss. Elise  female  58.0      0
# ...                                              ...     ...   ...    ...
# ...

# %% [markdown]
# 6. Fare less than 20

# %%
df.loc[df["Fare"] < 20, :]
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 2               3         1       3
# 4               5         0       3
# 5               6         0       3
# 8               9         1       3
# ...           ...       ...     ...
# 1301         1302         1       3
# 1303         1304         1       3
# 1304         1305         0       3
# 1306         1307         0       3
# 1307         1308         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 4                              Allen, Mr. William Henry    male  35.0      0
# 5                                      Moran, Mr. James    male   NaN      0
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %% [markdown]
# 7. Show female passengers

# %%
df.loc[df["Sex"] == "female", :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 8               9         1       3
# 9              10         1       2
# ...           ...       ...     ...
# 1300         1301         1       3
# 1301         1302         1       3
# 1302         1303         1       1
# 1303         1304         1       3
# 1305         1306         1       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %% [markdown]
# 8. Show Pclass 1 passengers

# %%
df.loc[df["Pclass"] == 1, :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 3               4         1       1
# 6               7         0       1
# 11             12         1       1
# 23             24         1       1
# ...           ...       ...     ...
# 1294         1295         0       1
# 1295         1296         0       1
# 1298         1299         0       1
# 1302         1303         1       1
# 1305         1306         1       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                               McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss. Elizabeth  female  58.0      0
# 23                         Sloper, Mr. William Thompson    male  28.0      0
# ...

# %% [markdown]
# LETS USE AND, OR

# %% [markdown]
#  Male AND survived

# %%
df.loc[(df["Sex"] == "male") & (df["Survived"] == 1), :]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Age above 30 AND survived

# %%
df.loc[(df["Age"] > 30) & (df["Survived"] == 1), :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 3               4         1       1
# 11             12         1       1
# 15             16         1       2
# 21             22         1       2
# ...           ...       ...     ...
# 1266         1267         1       1
# 1282         1283         1       1
# 1288         1289         1       1
# 1302         1303         1       1
# 1305         1306         1       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                             Bonnell, Miss. Elizabeth  female  58.0      0
# 15                     Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 21                                Beesley, Mr. Lawrence    male  34.0      0
# ...

# %% [markdown]
# Age below 18 AND survived

# %%
df.loc[(df["Age"] < 18) & (df["Survived"] == 1), :]
# Out:
#       PassengerId  Survived  Pclass                                      Name  \
# 9              10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10             11         1       3           Sandstrom, Miss. Marguerite Rut
# 22             23         1       3               McGowan, Miss. Anna "Annie"
# 39             40         1       3               Nicola-Yarred, Miss. Jamila
# 43             44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ...           ...       ...     ...                                       ...
# 1206         1207         1       3                      Hagardon, Miss. Kate
# 1217         1218         1       2              Becker, Miss. Ruth Elizabeth
# 1236         1237         1       3               Abelseth, Miss. Karen Marie
# 1245         1246         1       3   Dean, Miss. Elizabeth Gladys Millvina""
# 1300         1301         1       3                 Peacock, Miss. Treasteall
#
# ...

# %% [markdown]
# Fare above 100 AND survived

# %%
df.loc[(df["Fare"] > 100) & (df["Survived"] == 1), :]
# Out:
#       PassengerId  Survived  Pclass  \
# 31             32         1       1
# 88             89         1       1
# 195           196         1       1
# 215           216         1       1
# 258           259         1       1
# 268           269         1       1
# 269           270         1       1
# 299           300         1       1
# 305           306         1       1
# 306           307         1       1
# 307           308         1       1
# 311           312         1       1
# 318           319         1       1
# 319           320         1       1
# 325           326         1       1
# 334           335         1       1
# 337           338         1       1
# 341           342         1       1
# 380           381         1       1
# 390           391         1       1
# 393           394         1       1
# 435           436         1       1
# 537           538         1       1
# 550           551         1       1
# 581           582         1       1
# ...

# %% [markdown]
# Female AND age above 30

# %%
df.loc[(df["Sex"] == "female") & (df["Age"] > 30), :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 3               4         1       1
# 11             12         1       1
# 15             16         1       2
# 18             19         0       3
# ...           ...       ...     ...
# 1266         1267         1       1
# 1282         1283         1       1
# 1288         1289         1       1
# 1302         1303         1       1
# 1305         1306         1       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                             Bonnell, Miss. Elizabeth  female  58.0      0
# 15                     Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ...

# %% [markdown]
# Male AND Pclass 1

# %%
df.loc[(df["Sex"] == "male") & (df["Pclass"] == 1), :]
# Out:
#       PassengerId  Survived  Pclass                            Name   Sex  \
# 6               7         0       1         McCarthy, Mr. Timothy J  male
# 23             24         1       1    Sloper, Mr. William Thompson  male
# 27             28         0       1  Fortune, Mr. Charles Alexander  male
# 30             31         0       1        Uruchurtu, Don. Manuel E  male
# 34             35         0       1         Meyer, Mr. Edgar Joseph  male
# ...           ...       ...     ...                             ...   ...
# 1269         1270         0       1     Hipkins, Mr. William Edward  male
# 1281         1282         0       1      Payne, Mr. Vivian Ponsonby  male
# 1294         1295         0       1          Carrau, Mr. Jose Pedro  male
# 1295         1296         0       1    Frauenthal, Mr. Isaac Gerald  male
# 1298         1299         0       1      Widener, Mr. George Dunton  male
#
#        Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %% [markdown]
# Age above 40 AND Fare above 50

# %%
df.loc[(df["Age"] > 40) & (df["Fare"] > 50), :]
# Out:
#       PassengerId  Survived  Pclass  \
# 6               7         0       1
# 35             36         0       1
# 52             53         1       1
# 54             55         0       1
# 62             63         0       1
# ...           ...       ...     ...
# 1259         1260         1       1
# 1265         1266         1       1
# 1266         1267         1       1
# 1288         1289         1       1
# 1298         1299         0       1
#
#                                                    Name     Sex   Age  SibSp  \
# 6                               McCarthy, Mr. Timothy J    male  54.0      0
# 35                       Holverson, Mr. Alexander Oskar    male  42.0      1
# 52             Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 54                       Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 62                          Harris, Mr. Henry Birkhardt    male  45.0      1
# ...

# %% [markdown]
# Age below 18 OR female

# %%
df.loc[(df["Age"] < 18) | (df["Sex"] == "female"), :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 7               8         0       3
# 8               9         1       3
# ...           ...       ...     ...
# 1300         1301         1       3
# 1301         1302         1       3
# 1302         1303         1       1
# 1303         1304         1       3
# 1305         1306         1       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                        Palsson, Master. Gosta Leonard    male   2.0      3
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %% [markdown]
# Age above 30 OR survived

# %%
df.loc[(df["Age"] > 30) | (df["Survived"] == 1), :]
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# 6               7         0       1
# ...           ...       ...     ...
# 1301         1302         1       3
# 1302         1303         1       1
# 1303         1304         1       3
# 1305         1306         1       1
# 1306         1307         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# 6                               McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %% [markdown]
# Male OR Pclass 1

# %%
df.loc[(df["Sex"] == "male") | (df["Pclass"] == 1), :]
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 3               4         1       1
# 4               5         0       3
# 5               6         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# 5                                      Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# Age below 10 OR above 60

# %%
df.loc[(df["Age"] < 10) | (df["Age"] > 60), :]
# Out:
#       PassengerId  Survived  Pclass                                     Name  \
# 7               8         0       3           Palsson, Master. Gosta Leonard
# 10             11         1       3          Sandstrom, Miss. Marguerite Rut
# 16             17         0       3                     Rice, Master. Eugene
# 24             25         0       3            Palsson, Miss. Torborg Danira
# 33             34         0       2                    Wheadon, Mr. Edward H
# ...           ...       ...     ...                                      ...
# 1198         1199         0       3                Aks, Master. Philip Frank
# 1245         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 1270         1271         0       3              Asplund, Master. Carl Edgar
# 1280         1281         0       3              Palsson, Master. Paul Folke
# 1300         1301         1       3                Peacock, Miss. Treasteall
#
# ...

# %% [markdown]
# specific columns and condition

# %% [markdown]
# Name and Age of passengers who survived

# %%
df.loc[df["Survived"] == 1, ["Name", "Age"]]
# Out:
#                                                    Name   Age
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                                Heikkinen, Miss. Laina  26.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ...                                                 ...   ...
# 1300                          Peacock, Miss. Treasteall   3.0
# 1301                             Naughton, Miss. Hannah   NaN
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  37.0
# 1303                     Henriksson, Miss. Jenny Lovisa  28.0
# 1305                       Oliva y Ocana, Dona. Fermina  39.0
#
# [494 rows x 2 columns]

# %% [markdown]
# Name, Age and Fare where Fare is above 100

# %%
df.loc[df["Fare"] > 100, ["Name", "Age", "Fare"]]
# Out:
#                                                 Name   Age      Fare
# 27                    Fortune, Mr. Charles Alexander  19.0  263.0000
# 31    Spencer, Mrs. William Augustus (Marie Eugenie)   NaN  146.5208
# 88                        Fortune, Miss. Mabel Helen  23.0  263.0000
# 118                         Baxter, Mr. Quigg Edmond  24.0  247.5208
# 195                             Lurette, Miss. Elise  58.0  146.5208
# ...                                              ...   ...       ...
# 1262                       Wilson, Miss. Helen Alice  31.0  134.5000
# 1266                        Bowen, Miss. Grace Scott  45.0  262.3750
# 1291                         Bonnell, Miss. Caroline  30.0  164.8667
# 1298                      Widener, Mr. George Dunton  50.0  211.5000
# 1305                    Oliva y Ocana, Dona. Fermina  39.0  108.9000
#
# [84 rows x 3 columns]

# %% [markdown]
# Name, Age and Embarked of female passengers

# %%
df.loc[df["Sex"] == "female", ["Name", "Age", "Embarked"]]
# Out:
#                                                    Name   Age Embarked
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0        C
# 2                                Heikkinen, Miss. Laina  26.0        S
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0        S
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0        S
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  14.0        C
# ...                                                 ...   ...      ...
# 1300                          Peacock, Miss. Treasteall   3.0        S
# 1301                             Naughton, Miss. Hannah   NaN        Q
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  37.0        Q
# 1303                     Henriksson, Miss. Jenny Lovisa  28.0        S
# 1305                       Oliva y Ocana, Dona. Fermina  39.0        C
#
# [466 rows x 3 columns]

# %% [markdown]
# Name, Sex and Age of male survivors

# %%
df.loc[(df["Sex"] == "male") & (df["Survived"] == 1), ["Name", "Sex", "Age"]]
# Out:
#                                 Name   Sex   Age
# 17      Williams, Mr. Charles Eugene  male   NaN
# 21             Beesley, Mr. Lawrence  male  34.0
# 23      Sloper, Mr. William Thompson  male  28.0
# 36                  Mamee, Mr. Hanna  male   NaN
# 55                 Woolner, Mr. Hugh  male   NaN
# ..                               ...   ...   ...
# 838                  Chip, Mr. Chang  male  32.0
# 839             Marechal, Mr. Pierre  male   NaN
# 857           Daly, Mr. Peter Denis   male  51.0
# 869  Johnson, Master. Harold Theodor  male   4.0
# 889            Behr, Mr. Karl Howell  male  26.0
#
# [109 rows x 3 columns]

# %% [markdown]
# Name, Age, Fare and Pclass of female survivors with Fare above 50

# %%
df.loc[(df["Sex"] == "female") & (df["Survived"] == 1) & (df["Fare"] > 50), ["Name", "Age", "Fare", "Pclass"]]
# Out:
#                                                    Name   Age      Fare  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0   71.2833
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0   53.1000
# 31       Spencer, Mrs. William Augustus (Marie Eugenie)   NaN  146.5208
# 52             Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0   76.7292
# 61                                  Icard, Miss. Amelie  38.0   80.0000
# ...                                                 ...   ...       ...
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...  48.0   79.2000
# 1291                            Bonnell, Miss. Caroline  30.0  164.8667
# 1293                     Gibson, Miss. Dorothy Winifred  22.0   59.4000
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)  37.0   90.0000
# 1305                       Oliva y Ocana, Dona. Fermina  39.0  108.9000
#
#       Pclass
# 1          1
# 3          1
# 31         1
# 52         1
# 61         1
# ...      ...
# ...
